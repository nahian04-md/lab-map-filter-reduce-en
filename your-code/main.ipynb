# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %%
num_words_to_remove = 568

# %%
remaining_words = prophet[num_words_to_remove:]

# %%
cleaned_text = ' '.join(remaining_words)

# %%
output_file = "salida.text"

# %%
with open(output_file, 'w', encoding='utf8') as f:
    f.write(cleaned_text)

# %%
# Join back into text
print(f"Removed the first {num_words_to_remove} words.")
print(f"Total words after removal: {len(remaining_words)}")
print(f"Cleaned text saved to: {output_file}")
# Out:
# Removed the first 568 words.
# Total words after removal: 13069
# Cleaned text saved to: salida.text

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
type(prophet)
# Out:
# list

# %%
del prophet[0:568]

# %%
len(prophet)
# Out:
# 13069

# %%
# Join back into text
print(f"Removed the first 568 words.")
print(f"Total words after removal: {len(prophet)}")
# Out:
# Removed the first 568 words.
# Total words after removal: 13069

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
print(prophet[0:9])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # your code here

# %%
# your code here
import re

with open('../data/58585-0.txt', 'r', encoding='utf8') as f:
    text = f.read()

# %%
clean_text = re.sub(r'\[\d+\]|\(\d+\)|\{\d+\}', '', text)

# %%
print(clean_text[:13069])
# Out:
# The Project Gutenberg EBook of The Prophet, by Kahlil Gibran
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever.  You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org.  If you are not located in the United States, you'll
# have to check the laws of the country where you are located before using
# this ebook.
#
#
#
# Title: The Prophet
#
# Author: Kahlil Gibran
#
# Release Date: January 1, 2019 [EBook #58585]
# Last Updated: January 3, 2018
#
#
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK THE PROPHET ***
#
#
#
#
# Produced by David Widger from page images generously
# provided by the Internet Archive
#
#
# Transcriber's Note: Page numbers, ie: , are included in this
# ...

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here
references = [w for w in prophet 
if '[' in w or ']' in w or 
   '(' in w or ')' in w or 
   '{' in w or '}' in w or 
   w.isdigit()]

print(references[:])  # Show first 20 possible references
# Out:
# ['the{7}', '{8}Long\nwere', 'and\n{9}the', '{10}And', '{11}Shall', '{12}he\nhimself', 'deeper\nsecret.\n\n*****\n\n[Illustration:', '0020]\n\nAnd', 'spirit,\n{13}and', '{14}And\nshe', 'I\n{15}speak', 'and\n{16}caresses', '{17}your', '{18}To\nknow', 'lips.\n\n[Illustration:', '0029]\n\n*****', '*****\n\n{19}Then', '{20}Sing', 'shadow.\n\n[Illustration:', '0032]\n\n*****', '*****\n\n{21}And', '{22}For\nlife', '*****\n\n{23}Then', 'the\n{24}much', 'earth.\n\n[Illustration:', '0039]\n\nIt', 'for\n{25}one', 'rend\n{26}their', 'father.\n\n[Illustration:', '0042]\n\n*****', '*****\n\n{27}Then', 'consumed.\n{28}For', 'wine,\n{29}let', 'winepress.\n\n*****\n*****\n\n{30}', 'dream,\n{31}assigned', 'bind\n{32}yourself', '{33}And', '{34}And', '*****\n\n{35}Then', 'in\n{36}your', '*****\n\n{37}Then', 'you\n{38}might', 'that\n{39}enters', 'that\n{40}covers', '*****\n\n{41}And', '{42}Forget', '*****\n\n{43}And', '{44}And\nsuffer', '*****\n\n{45}Then', 'serpent.\n{46}But', '{47}So', 'god-self.\n\n[I
# ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # your code here
    return references.split('\n')
    print(references)

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here
def split_references_on_linebreak(ref_list):

    split_refs = []
    for ref in ref_list:
        split_refs.extend(ref.split('\n'))  
    return split_refs

prophet_line = split_references_on_linebreak(references)

print(prophet_line [:20])
# Out:
# ['the{7}', '{8}Long', 'were', 'and', '{9}the', '{10}And', '{11}Shall', '{12}he', 'himself', 'deeper', 'secret.', '', '*****', '', '[Illustration:', '0020]', '', 'And', 'spirit,', '{13}and']

# %%
type(prophet_line)
# Out:
# list

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [part for ref in references for part in ref.split('\n')]
print(prophet_flat)
# Out:
# ['the{7}', '{8}Long', 'were', 'and', '{9}the', '{10}And', '{11}Shall', '{12}he', 'himself', 'deeper', 'secret.', '', '*****', '', '[Illustration:', '0020]', '', 'And', 'spirit,', '{13}and', '{14}And', 'she', 'I', '{15}speak', 'and', '{16}caresses', '{17}your', '{18}To', 'know', 'lips.', '', '[Illustration:', '0029]', '', '*****', '*****', '', '{19}Then', '{20}Sing', 'shadow.', '', '[Illustration:', '0032]', '', '*****', '*****', '', '{21}And', '{22}For', 'life', '*****', '', '{23}Then', 'the', '{24}much', 'earth.', '', '[Illustration:', '0039]', '', 'It', 'for', '{25}one', 'rend', '{26}their', 'father.', '', '[Illustration:', '0042]', '', '*****', '*****', '', '{27}Then', 'consumed.', '{28}For', 'wine,', '{29}let', 'winepress.', '', '*****', '*****', '', '{30}', 'dream,', '{31}assigned', 'bind', '{32}yourself', '{33}And', '{34}And', '*****', '', '{35}Then', 'in', '{36}your', '*****', '', '{37}Then', 'you', '{38}might', 'that', '{39}enters', 'that', '{40}covers', '*****', '', '{41}And
# ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
   # word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
len(prophet)
# Out:
# 13069

# %%
# your code here
words_list = ['and', 'the', 'a', 'an']

# %%
def word_filter_from_text(words_list):

    word = input("Enter a word from prophet: ")
    return word.lower() not in words_list  

result = word_filter_from_text(words_list)
print(f"Result: {result}")
# Out:
# Result: True

# %%
def word_filter(word):
    return word.lower() not in words_list

prophet_filter = list(filter(word_filter, prophet))
print(prophet_filter[:50])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'his', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'in', 'city\nof', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to\nreturn', 'bear', 'him', 'back', 'to', 'isle', 'of\nhis', 'birth.\n\nAnd', 'in', 'twelfth', 'year,', 'on', 'seventh\nday', 'of', 'Ielool,', 'month', 'of', 'reaping,', 'he\nclimbed', 'hill', 'without', 'city', 'walls\nand', 'looked', 'seaward;', 'he', 'beheld', 'his\nship']

# %%
type(prophet_filter)
# Out:
# list

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
from functools import reduce

def concatenate(a, b):
    return a + " " + b

def concat_space(prophet_filter):

    prophet_filter = list(map(str, prophet_filter))

    if not prophet_filter:
        return ""
    
    prophet_string = reduce(concatenate, prophet_filter)
    print(prophet_string)

    return prophet_string
